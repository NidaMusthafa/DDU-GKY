# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Car_sales.csv')
data.sample(10)
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 25     Chevrolet           Prizm              32.299                9.125
# 17      Cadillac          Catera              11.185               18.225
# 28      Chrysler   Sebring Coupe               7.854               12.360
# 94    Mercedes-B         S-Class              16.774               50.375
# 83    Mitsubishi          3000GT               0.110               20.940
# 34      Chrysler            300M              30.696                  NaN
# 130       Saturn              SC              24.546               10.590
# 69          Jeep  Grand Cherokee             157.040               18.810
# 100   Mercedes-B         M-Class              28.976                  NaN
# 141       Toyota          Sienna              65.119                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 25     Passenger              13.960          1.8       120.0       97.1
# ...

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
data.tail(10)
# Out:
#     Manufacturer   Model  Sales_in_thousands  __year_resale_value  \
# 147   Volkswagen  Passat              51.102               16.725
# 148   Volkswagen  Cabrio               9.569               16.575
# 149   Volkswagen     GTI               5.596               13.760
# 150   Volkswagen  Beetle              49.463                  NaN
# 151        Volvo     S40              16.957                  NaN
# 152        Volvo     V40               3.545                  NaN
# 153        Volvo     S70              15.245                  NaN
# 154        Volvo     V70              17.531                  NaN
# 155        Volvo     C70               3.493                  NaN
# 156        Volvo     S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 147    Passenger               21.20          1.8       150.0      106.4
# 148    Passenger               19.99          2.0       115.0       97.4
# ...

# %% [markdown]
# ### Drop na

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    object
# ...

# %%
data.values
# Out:
# array([['Acura', 'Integra', 16.919, ..., 28.0, '2/2/2012', 58.28014952],
#        ['Acura', 'TL', 39.384, ..., 25.0, '6/3/2011', 91.37077766],
#        ['Acura', 'CL', 14.114, ..., 26.0, '1/4/2012', nan],
#        ...,
#        ['Volvo', 'V70', 17.531, ..., 25.0, '6/25/2011', 71.1559776],
#        ['Volvo', 'C70', 3.493, ..., 23.0, '4/26/2011', 101.6233572],
#        ['Volvo', 'S80', 18.969, ..., 24.0, '11/14/2011', 85.73565451]],
#       dtype=object)

# %%
data.shape
# Out:
# (157, 16)

# %%
data.size
# Out:
# 2512

# %% [markdown]
# ### Checking the contents in latest launch column

# %%
data.Latest_Launch.nunique()
# Out:
# 130

# %% [markdown]
# #### Change its datatype in to datetime

# %%
data['Latest_Launch']=pd.to_datetime(data.Latest_Launch)

# %%
data.head(10)
# Out:
#    Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0         Acura  Integra              16.919               16.360
# 1         Acura       TL              39.384               19.875
# 3         Acura       RL               8.588               29.725
# 4          Audi       A4              20.397               22.255
# 5          Audi       A6              18.780               23.555
# 6          Audi       A8               1.380               39.000
# 8           BMW     328i               9.231               28.675
# 9           BMW     528i              17.527               36.125
# 10        Buick  Century              91.561               12.475
# 11        Buick    Regal              39.350               13.740
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0     Passenger              21.500          1.8       140.0      101.2
# 1     Passenger              28.400          3.2       225.0      108.1
# ...

# %% [markdown]
# ### Check the dtype of it

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    datetime64[ns]
# ...

# %% [markdown]
# ## Extracting year, month ,day from the latest_launch column

# %%
data['year']=pd.DatetimeIndex(data.Latest_Launch).year

# %%
data['month']=pd.DatetimeIndex(data.Latest_Launch).month

# %%
data['day']=pd.DatetimeIndex(data.Latest_Launch).day

# %%
data.head(10)
# Out:
#    Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0         Acura  Integra              16.919               16.360
# 1         Acura       TL              39.384               19.875
# 3         Acura       RL               8.588               29.725
# 4          Audi       A4              20.397               22.255
# 5          Audi       A6              18.780               23.555
# 6          Audi       A8               1.380               39.000
# 8           BMW     328i               9.231               28.675
# 9           BMW     528i              17.527               36.125
# 10        Buick  Century              91.561               12.475
# 11        Buick    Regal              39.350               13.740
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0     Passenger              21.500          1.8       140.0      101.2
# 1     Passenger              28.400          3.2       225.0      108.1
# ...

# %% [markdown]
# ### Lets convert the data type of fuel efficiency into integer

# %%
data.Fuel_efficiency = data.Fuel_efficiency.astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    int32
#  14  Latest_Launch        117 non-null    datetime64[ns]
# ...

# %% [markdown]
# ## Converting numerical column into categorical column

# %%
data.month.replace({
    1:'JANUARY',
    2:'FEBRUARY',
    3:'MARCH',
    4:'APRIL',
    5:'MAY',
    6:'JUNE',
    7:'JULY',
    8:'AUGUST',
    9:'SEPTEMBER',
    10:'OCTBER',
    11:'NOVEMBER',
    12:'DECEMBER'
},inplace=True)

# %%
data.sample(10)
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 80    Mitsubishi        Eclipse              42.541               10.395
# 20     Chevrolet         Malibu             135.126               11.225
# 125      Porsche  Carrera Coupe               1.280               60.625
# 84    Mitsubishi        Montero              11.337               19.125
# 94    Mercedes-B        S-Class              16.774               50.375
# 73         Lexus          LS400               6.375               40.375
# 102       Nissan         Altima              88.094               11.295
# 35         Dodge           Neon              76.034                7.750
# 17      Cadillac         Catera              11.185               18.225
# 146   Volkswagen          Jetta              83.721               13.240
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 80     Passenger              19.047          2.4       154.0      100.8
# ...

# %% [markdown]
# ### Label encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data["le_vehicle"]= le.fit_transform(data.Vehicle_type)

# %%
data.sample(10)
# Out:
#     Manufacturer       Model  Sales_in_thousands  __year_resale_value  \
# 55          Ford      Ranger             220.650                7.850
# 40         Dodge  Ram Pickup             227.061               15.060
# 36         Dodge     Avenger               4.734               12.545
# 47          Ford     Mustang             113.369               12.760
# 77       Lincoln    Town car              48.911               21.725
# 24     Chevrolet    Corvette              17.947               36.225
# 121      Pontiac  Grand Prix              92.364               14.010
# 93    Mercedes-B     E-Class              27.602               41.450
# 37         Dodge     Stratus              71.186               10.185
# 130       Saturn          SC              24.546               10.590
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 55           Car              12.050          2.5       119.0      117.5
# ...

# %%
data['le_manufacturer'] = le.fit_transform(data.Manufacturer)

# %%
data.sample(10)
# Out:
#     Manufacturer        Model  Sales_in_thousands  __year_resale_value  \
# 16      Cadillac     Eldorado               6.536               25.725
# 9            BMW         528i              17.527               36.125
# 114     Plymouth         Neon              32.734                7.750
# 137       Toyota        Camry             247.994               13.245
# 6           Audi           A8               1.380               39.000
# 19     Chevrolet     Cavalier             145.519                9.250
# 12         Buick  Park Avenue              27.851               20.190
# 13         Buick      LeSabre              83.257               13.360
# 4           Audi           A4              20.397               22.255
# 139       Toyota       Celica              33.269               15.445
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 16     Passenger              39.665          4.6       275.0      108.0
# ...

# %%
data['le_model'] = le.fit_transform(data.Model)
data.sample(10)
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 43         Dodge         Dakota             111.313               11.260
# 82    Mitsubishi       Diamante               5.711               16.575
# 147   Volkswagen         Passat              51.102               16.725
# 85    Mitsubishi  Montero Sport              39.348               13.880
# 53          Ford       Windstar             155.787               13.175
# 84    Mitsubishi        Montero              11.337               19.125
# 125      Porsche  Carrera Coupe               1.280               60.625
# 9            BMW           528i              17.527               36.125
# 143       Toyota        4Runner              68.411               19.425
# 49          Ford         Taurus             245.815               10.055
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 43           Car              16.980          2.5       120.0      131.0
# ...

# %%
data['le_Sales_in_thousands'] = le.fit_transform(data.Sales_in_thousands)
data.sample(10)
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 28      Chrysler  Sebring Coupe               7.854               12.360
# 84    Mitsubishi        Montero              11.337               19.125
# 68          Jeep       Cherokee              80.556               13.775
# 17      Cadillac         Catera              11.185               18.225
# 149   Volkswagen            GTI               5.596               13.760
# 131       Saturn             SW               5.223               10.790
# 29      Chrysler  Sebring Conv.              32.775               14.180
# 67          Jeep       Wrangler              55.557               13.475
# 60         Honda       Passport              12.855               17.525
# 73         Lexus          LS400               6.375               40.375
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 28     Passenger              19.840          2.5       163.0      103.7
# ...

# %%
data['le_ __year_resale_value'] = le.fit_transform(data. __year_resale_value)
data.sample(10)
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 87       Mercury          Cougar              26.529               13.890
# 1          Acura              TL              39.384               19.875
# 62       Hyundai          Accent              41.184                5.860
# 5           Audi              A6              18.780               23.555
# 77       Lincoln        Town car              48.911               21.725
# 25     Chevrolet           Prizm              32.299                9.125
# 69          Jeep  Grand Cherokee             157.040               18.810
# 64       Hyundai          Sonata              29.450                8.910
# 143       Toyota         4Runner              68.411               19.425
# 31      Chrysler          Cirrus              32.306               12.640
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 87     Passenger              16.540          2.0       125.0      106.4
# ...

# %%
data['le_Vehicle_type'] = le.fit_transform(data.Vehicle_type)
data.sample(10)
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 113   Oldsmobile      Silhouette              24.361               15.240
# 0          Acura         Integra              16.919               16.360
# 13         Buick         LeSabre              83.257               13.360
# 126      Porsche  Carrera Cabrio               1.866               67.550
# 103       Nissan          Maxima              79.853               15.125
# 25     Chevrolet           Prizm              32.299                9.125
# 105       Nissan      Pathfinder              42.574               17.810
# 6           Audi              A8               1.380               39.000
# 138       Toyota          Avalon              63.849               18.140
# 41         Dodge       Ram Wagon              16.767               15.510
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 113          Car              25.345          3.4       185.0      120.0
# ...

# %%
data['le_Price_in_thousands'] = le.fit_transform(data.Price_in_thousands)
data.sample(10)
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 146   Volkswagen           Jetta              83.721               13.240
# 85    Mitsubishi   Montero Sport              39.348               13.880
# 21     Chevrolet          Lumina              24.629               10.310
# 62       Hyundai          Accent              41.184                5.860
# 54          Ford      Expedition             125.338               23.575
# 4           Audi              A4              20.397               22.255
# 95    Mercedes-B        SL-Class               3.311               58.600
# 131       Saturn              SW               5.223               10.790
# 126      Porsche  Carrera Cabrio               1.866               67.550
# 120      Pontiac        Firebird              19.911               17.805
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 146    Passenger              16.700          2.0       115.0       98.9
# ...

# %%
data['le_Engine_size'] = le.fit_transform(data.Engine_size)
data.sample(10)
# Out:
#     Manufacturer       Model  Sales_in_thousands  __year_resale_value  \
# 26     Chevrolet       Metro              21.855                5.160
# 113   Oldsmobile  Silhouette              24.361               15.240
# 13         Buick     LeSabre              83.257               13.360
# 148   Volkswagen      Cabrio               9.569               16.575
# 59         Honda        CR-V              73.203               17.710
# 6           Audi          A8               1.380               39.000
# 130       Saturn          SC              24.546               10.590
# 40         Dodge  Ram Pickup             227.061               15.060
# 4           Audi          A4              20.397               22.255
# 32      Chrysler         LHS              13.462               17.325
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26     Passenger               9.235          1.0        55.0       93.1
# ...

# %%
data['le_Wheelbase'] = le.fit_transform(data.Wheelbase)
data.sample(10)
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 103       Nissan         Maxima              79.853               15.125
# 143       Toyota        4Runner              68.411               19.425
# 79    Mitsubishi         Mirage              26.232                8.325
# 22     Chevrolet    Monte Carlo              42.593               11.525
# 108   Oldsmobile        Cutlass               1.112               11.240
# 136       Toyota        Corolla             142.535               10.025
# 137       Toyota          Camry             247.994               13.245
# 82    Mitsubishi       Diamante               5.711               16.575
# 16      Cadillac       Eldorado               6.536               25.725
# 85    Mitsubishi  Montero Sport              39.348               13.880
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 103    Passenger              26.249          3.0       222.0      108.3
# ...

# %%
data['le_Horsepower'] = le.fit_transform(data.Horsepower)
data.sample(10)
# Out:
#     Manufacturer       Model  Sales_in_thousands  __year_resale_value  \
# 11         Buick       Regal              39.350               13.740
# 57         Honda       Civic             199.685                9.850
# 121      Pontiac  Grand Prix              92.364               14.010
# 32      Chrysler         LHS              13.462               17.325
# 9            BMW        528i              17.527               36.125
# 42         Dodge     Ram Van              31.038               13.425
# 35         Dodge        Neon              76.034                7.750
# 105       Nissan  Pathfinder              42.574               17.810
# 17      Cadillac      Catera              11.185               18.225
# 114     Plymouth        Neon              32.734                7.750
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 11     Passenger              25.300          3.8       240.0      109.0
# ...

# %%
data['le_Width'] = le.fit_transform(data.Width)
data.sample(10)
# Out:
#     Manufacturer       Model  Sales_in_thousands  __year_resale_value  \
# 122      Pontiac  Bonneville              35.945               13.225
# 32      Chrysler         LHS              13.462               17.325
# 92    Mercedes-B     C-Class              18.392               26.050
# 86       Mercury    Mystique              14.351                8.800
# 41         Dodge   Ram Wagon              16.767               15.510
# 113   Oldsmobile  Silhouette              24.361               15.240
# 129       Saturn          SL              80.620                9.200
# 47          Ford     Mustang             113.369               12.760
# 70         Lexus       ES300              24.072               26.975
# 35         Dodge        Neon              76.034                7.750
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 122    Passenger              23.755          3.8       205.0      112.2
# ...

# %%
data['le_Length'] = le.fit_transform(data.Length)
data.sample(10)
# Out:
#     Manufacturer     Model  Sales_in_thousands  __year_resale_value  \
# 46          Ford    Escort              70.227                7.425
# 56          Ford  F-Series             540.561               15.075
# 8            BMW      328i               9.231               28.675
# 149   Volkswagen       GTI               5.596               13.760
# 25     Chevrolet     Prizm              32.299                9.125
# 1          Acura        TL              39.384               19.875
# 84    Mitsubishi   Montero              11.337               19.125
# 108   Oldsmobile   Cutlass               1.112               11.240
# 23     Chevrolet    Camaro              26.402               13.025
# 111   Oldsmobile    Aurora              14.690               19.890
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 46     Passenger              12.070          2.0       110.0       98.4
# ...

# %%
data['le_Curb_weight'] = le.fit_transform(data.Curb_weight)
data.sample(10)
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 80    Mitsubishi         Eclipse              42.541               10.395
# 10         Buick         Century              91.561               12.475
# 126      Porsche  Carrera Cabrio               1.866               67.550
# 68          Jeep        Cherokee              80.556               13.775
# 64       Hyundai          Sonata              29.450                8.910
# 77       Lincoln        Town car              48.911               21.725
# 59         Honda            CR-V              73.203               17.710
# 144       Toyota    Land Cruiser               9.835               34.080
# 14      Cadillac         DeVille              63.729               22.525
# 52          Ford        Explorer             276.747               16.640
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 80     Passenger              19.047          2.4       154.0      100.8
# ...

# %%
data['le_Fuel_capacity'] = le.fit_transform(data.Fuel_capacity)
data.sample(10)
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 29      Chrysler  Sebring Conv.              32.775               14.180
# 47          Ford        Mustang             113.369               12.760
# 86       Mercury       Mystique              14.351                8.800
# 60         Honda       Passport              12.855               17.525
# 20     Chevrolet         Malibu             135.126               11.225
# 25     Chevrolet          Prizm              32.299                9.125
# 65      Infiniti            I30              23.713               19.690
# 129       Saturn             SL              80.620                9.200
# 130       Saturn             SC              24.546               10.590
# 142       Toyota           RAV4              25.106               13.325
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 29     Passenger              24.495          2.5       168.0      106.0
# ...

# %%
data['le_Latest_Launch'] = le.fit_transform(data.Latest_Launch)
data.sample(10)
# Out:
#     Manufacturer        Model  Sales_in_thousands  __year_resale_value  \
# 42         Dodge      Ram Van              31.038               13.425
# 83    Mitsubishi       3000GT               0.110               20.940
# 147   Volkswagen       Passat              51.102               16.725
# 104       Nissan        Quest              27.308               15.380
# 93    Mercedes-B      E-Class              27.602               41.450
# 54          Ford   Expedition             125.338               23.575
# 118      Pontiac      Sunfire              51.645               13.790
# 46          Ford       Escort              70.227                7.425
# 23     Chevrolet       Camaro              26.402               13.025
# 12         Buick  Park Avenue              27.851               20.190
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 42           Car              18.575          3.9       175.0      127.2
# ...
